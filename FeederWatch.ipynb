# %% [markdown]
# FeederWatch

# %%
import pandas as pd
import numpy as nm

# %%
feederwatch  = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2023/2023-01-10/PFW_2021_public.csv")

# %%
site_data = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2023/2023-01-10/PFW_count_site_data_public_2021.csv")

# %%
feederwatch.head()
# Out:
#       loc_id   latitude   longitude subnational1_code  \
# 0    L981010  52.129760 -122.135470             CA-BC
# 1   L3161698  43.832207 -123.092405             US-OR
# 2  L13210778  39.721470  -75.933660             US-MD
# 3  L13258348  42.217874  -83.672300             US-MI
# 4    L149639  32.749921  -79.941582             US-SC
#
#             entry_technique     sub_id         obs_id  Month  Day  Year  ...  \
# 0  POSTCODE LAT/LONG LOOKUP  S83206450  OBS1092604618      3    4  2021  ...
# 1       /GOOGLE_MAP/ZOOM:18  S78031190  OBS1036509564     12   19  2020  ...
# 2       /GOOGLE_MAP/ZOOM:15  S81318993  OBS1073386105      2   13  2021  ...
# 3       /GOOGLE_MAP/ZOOM:15  S79251313  OBS1051702542      1   13  2021  ...
# 4           PointMaker1.0_2  S79183993  OBS1050809672      1   11  2021  ...
#
#   how_many valid  reviewed  day1_am  day1_pm  day2_am  day2_pm  \
# 0       20     1         0        1        0        1        0
# ...

# %%
feederwatch_df = pd.DataFrame(data=feederwatch)

# %%
feederwatch_df.fillna(0)
# Out:
#           loc_id   latitude   longitude subnational1_code  \
# 0        L981010  52.129760 -122.135470             CA-BC
# 1       L3161698  43.832207 -123.092405             US-OR
# 2      L13210778  39.721470  -75.933660             US-MD
# 3      L13258348  42.217874  -83.672300             US-MI
# 4        L149639  32.749921  -79.941582             US-SC
# ...          ...        ...         ...               ...
# 99995  L10152877  40.249349  -74.835820             US-NJ
# 99996  L12811147  42.739059  -83.429081             US-MI
# 99997   L3166096  35.308537 -120.844680             US-CA
# 99998  L12873662  32.900101  -96.745300             US-TX
# 99999    L277306  42.355489  -76.947016             US-NY
#
#                 entry_technique     sub_id         obs_id  Month  Day  Year  \
# 0      POSTCODE LAT/LONG LOOKUP  S83206450  OBS1092604618      3    4  2021
# 1           /GOOGLE_MAP/ZOOM:18  S78031190  OBS1036509564     12   19  2020
# ...

# %%
right_line_chart = feederwatch[["Year","Month", "how_many"]].groupby(["Year", "Month"]).sum("how_many")

# %%
right_line_chart
# Out:
#             how_many
# Year Month
# 2020 11        41162
#      12        70876
# 2021 1         86776
#      2         75566
#      3         60615
#      4         35677

# %%
left_bar_chart = feederwatch[['species_code', 'Year', 'how_many']]

# %%
def left_bar_chart2 (year1):
    left_bar_chart = feederwatch[['species_code', 'Year', 'how_many']]
    left_bar_chart[left_bar_chart['Year'] == year1]
    return left_bar_chart

# %%
left_bar_chart = feederwatch[['species_code', 'Year', 'how_many']]

# %%
left_bar_chart[left_bar_chart['Year'] == 2021 ]
# Out:
#       species_code  Year  how_many
# 0           amegfi  2021        20
# 2           tuftit  2021         2
# 3           houspa  2021         2
# 4           balori  2021        10
# 5           norcar  2021         2
# ...            ...   ...       ...
# 99995       norfli  2021         1
# 99996       moudov  2021         8
# 99997       calqua  2021        23
# 99998       blujay  2021         1
# 99999       haiwoo  2021         2
#
# [69714 rows x 3 columns]
